# %%
pip install ibm_watson
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ibm_cloud_sdk_core
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ibm_watson import TextToSpeechV1

# %%
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
api = IAMAuthenticator("DgByQ1nq-13iiD-qOUZij5iZc55EYxZ8nLNTdJTyKtyR")

# %%
text_2_speech = TextToSpeechV1(authenticator=api)

# %%
text_2_speech.set_service_url("https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/b8c47780-f8e8-4895-8d00-cb9420407326")

# %%
with open("earn_me.mp3","wb") as audiofile:
    audiofile.write(
        text_2_speech.synthesize("I am not a toy you can play with when you are bored, or lonely, or horny. I am not the girl the guy gets at the end of the movie. I am not a fantasy. If you want me, earn me!", accept="audio/mp3").get_result().content
    )
